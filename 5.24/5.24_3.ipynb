# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
tips.describe(include = 'float')
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.sample() # random하게 뽑아오기
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 152       17.26  2.74  Male     No  Sun  Dinner     3

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 118       12.43  1.80  Female     No  Thur   Lunch     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 212       48.33  9.00    Male     No   Sat  Dinner     4
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2

# %%
import pandas as pd

# %%
accidents = pd.read_csv('a.csv',engine = 'python',encoding = 'cp949')

# %%
accidents
# Out:
#       시도  시군구 사고유형대분류        사고유형  발생건수  사망자수  부상자수   중상   경상  부상신고
# 0     서울  종로구    차대사람         횡단중   126     1   129   71   51     7
# 1     서울  종로구    차대사람       차도통행중    74     3    72   19   44     9
# 2     서울  종로구    차대사람  길가장자리구역통행중    35     0    35    7   23     5
# 3     서울  종로구    차대사람       보도통행중    28     0    32   11   14     7
# 4     서울  종로구    차대사람          기타    73     0    75   24   36    15
# 5     서울  종로구     차대차        정면충돌    23     0    35   13   18     4
# 6     서울  종로구     차대차        측면충돌   448     2   652  111  457    84
# 7     서울  종로구     차대차       후진중충돌    16     0    20    1   19     0
# 8     서울  종로구     차대차          추돌   211     0   372   38  304    30
# 9     서울  종로구     차대차          기타    59     0    80   15   50    15
# 10    서울  종로구    차량단독          전도    11     0    12    3    2     7
# 11    서울  종로구    차량단독       공작물충돌     8     0     8    1    4     3
# 12    서울  종로구    차량단독          기타    22     0    24    6   17     1
# ...

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3255 entries, 0 to 3254
# Data columns (total 10 columns):
# 시도         3255 non-null object
# 시군구        3255 non-null object
# 사고유형대분류    3255 non-null object
# 사고유형       3255 non-null object
# 발생건수       3255 non-null int64
# 사망자수       3255 non-null int64
# 부상자수       3255 non-null int64
# 중상         3255 non-null int64
# 경상         3255 non-null int64
# 부상신고       3255 non-null int64
# dtypes: int64(6), object(4)
# memory usage: 254.4+ KB

# %%
accidents.describe()
# Out:
#               발생건수         사망자수         부상자수           중상           경상  \
# count  3255.000000  3255.000000  3255.000000  3255.000000  3255.000000
# mean     66.712135     1.161598    99.243318    22.813518    69.895853
# std     149.823021     1.922356   240.649627    45.094825   183.574030
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       4.500000     0.000000     5.000000     2.000000     2.000000
# 50%      14.000000     0.000000    17.000000     6.000000     9.000000
# 75%      50.500000     2.000000    68.000000    22.000000    40.000000
# max    1708.000000    21.000000  2931.000000   533.000000  2299.000000
#
#               부상신고
# count  3255.000000
# mean      6.533948
# std      18.823657
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       4.000000
# max     241.000000

# %%
accidents.describe(include = 'object')
# Out:
#           시도   시군구 사고유형대분류  사고유형
# count   3255  3255    3255  3255
# unique    17   206       4    15
# top       경기    중구     차대차    기타
# freq     446    84    1128   672

# %%
accidents.head(10)
# Out:
#    시도  시군구 사고유형대분류        사고유형  발생건수  사망자수  부상자수   중상   경상  부상신고
# 0  서울  종로구    차대사람         횡단중   126     1   129   71   51     7
# 1  서울  종로구    차대사람       차도통행중    74     3    72   19   44     9
# 2  서울  종로구    차대사람  길가장자리구역통행중    35     0    35    7   23     5
# 3  서울  종로구    차대사람       보도통행중    28     0    32   11   14     7
# 4  서울  종로구    차대사람          기타    73     0    75   24   36    15
# 5  서울  종로구     차대차        정면충돌    23     0    35   13   18     4
# 6  서울  종로구     차대차        측면충돌   448     2   652  111  457    84
# 7  서울  종로구     차대차       후진중충돌    16     0    20    1   19     0
# 8  서울  종로구     차대차          추돌   211     0   372   38  304    30
# 9  서울  종로구     차대차          기타    59     0    80   15   50    15

# %%
type(tips['total_bill'])
# Out:
# pandas.core.series.Series

# %%
tips.total_bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
# 6       8.77
# 7      26.88
# 8      15.04
# 9      14.78
# 10     10.27
# 11     35.26
# 12     15.42
# 13     18.43
# 14     14.83
# 15     21.58
# 16     10.33
# 17     16.29
# 18     16.97
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 29     19.65
#        ...
# 214    28.17
# 215    12.90
# 216    28.15
# 217    11.59
# 218     7.74
# 219    30.14
# 220    12.16
# 221    13.42
# 222     8.58
# 223    15.98
# 224    13.42
# 225    16.27
# 226    10.09
# 227    20.45
# 228    13.28
# 229    22.12
# 230    24.01
# 231    15.69
# 232    11.61
# 233    10.77
# 234    15.53
# 235    10.07
# 236    12.60
# 237    32.83
# 238    35.83
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips[['tip','total_bill']]
# Out:
#       tip  total_bill
# 0    1.01       16.99
# 1    1.66       10.34
# 2    3.50       21.01
# 3    3.31       23.68
# 4    3.61       24.59
# 5    4.71       25.29
# 6    2.00        8.77
# 7    3.12       26.88
# 8    1.96       15.04
# 9    3.23       14.78
# 10   1.71       10.27
# 11   5.00       35.26
# 12   1.57       15.42
# 13   3.00       18.43
# 14   3.02       14.83
# 15   3.92       21.58
# 16   1.67       10.33
# 17   3.71       16.29
# 18   3.50       16.97
# 19   3.35       20.65
# 20   4.08       17.92
# 21   2.75       20.29
# 22   2.23       15.77
# 23   7.58       39.42
# 24   3.18       19.82
# 25   2.34       17.81
# 26   2.00       13.37
# 27   2.00       12.69
# 28   4.30       21.70
# 29   3.00       19.65
# ..    ...         ...
# 214  6.50       28.17
# 215  1.10       12.90
# 216  3.00       28.15
# 217  1.50       11.59
# 218  1.44        7.74
# 219  3.09       30.14
# 220  2.20       12.16
# 221  3.48       13.42
# 222  1.92        8.58
# ...

# %%
my_tip = tips[['tip','total_bill']].copy()

# %%
my_tip
# Out:
#       tip  total_bill
# 0    1.01       16.99
# 1    1.66       10.34
# 2    3.50       21.01
# 3    3.31       23.68
# 4    3.61       24.59
# 5    4.71       25.29
# 6    2.00        8.77
# 7    3.12       26.88
# 8    1.96       15.04
# 9    3.23       14.78
# 10   1.71       10.27
# 11   5.00       35.26
# 12   1.57       15.42
# 13   3.00       18.43
# 14   3.02       14.83
# 15   3.92       21.58
# 16   1.67       10.33
# 17   3.71       16.29
# 18   3.50       16.97
# 19   3.35       20.65
# 20   4.08       17.92
# 21   2.75       20.29
# 22   2.23       15.77
# 23   7.58       39.42
# 24   3.18       19.82
# 25   2.34       17.81
# 26   2.00       13.37
# 27   2.00       12.69
# 28   4.30       21.70
# 29   3.00       19.65
# ..    ...         ...
# 214  6.50       28.17
# 215  1.10       12.90
# 216  3.00       28.15
# 217  1.50       11.59
# 218  1.44        7.74
# 219  3.09       30.14
# 220  2.20       12.16
# 221  3.48       13.42
# 222  1.92        8.58
# ...

# %%
tips[[True,True,True,True,True,True,True]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-a8eda41b8b4e> in <module>
# ----> 1 tips[[True,True,True,True,True,True,True]]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2961         elif len(key) != len(self.index):
#    2962             raise ValueError('Item wrong length %d instead of %d.' %
# -> 2963                              (len(key), len(self.index)))
#    2964
#    2965         # check_bool_indexer will throw exception if Series key cannot
#
# ...

# %%
tips.select_dtypes('category')
# Out:
#         sex smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# 5      Male     No   Sun  Dinner
# 6      Male     No   Sun  Dinner
# 7      Male     No   Sun  Dinner
# 8      Male     No   Sun  Dinner
# 9      Male     No   Sun  Dinner
# 10     Male     No   Sun  Dinner
# 11   Female     No   Sun  Dinner
# 12     Male     No   Sun  Dinner
# 13     Male     No   Sun  Dinner
# 14   Female     No   Sun  Dinner
# 15     Male     No   Sun  Dinner
# 16   Female     No   Sun  Dinner
# 17     Male     No   Sun  Dinner
# 18   Female     No   Sun  Dinner
# 19     Male     No   Sat  Dinner
# 20     Male     No   Sat  Dinner
# 21   Female     No   Sat  Dinner
# 22   Female     No   Sat  Dinner
# 23     Male     No   Sat  Dinner
# 24     Male     No   Sat  Dinner
# 25     Male     No   Sat  Dinner
# 26     Male     No   Sat  Dinner
# ...

# %%
tips.loc[0:5] #5까지 가져옴
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4

# %%
tips.iloc[0:5] #python처럼 4까지 가져옴
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.iloc[0:5 , :3]
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
 tips.loc[0:5,:'time'] #loc는 이름 기반!!!!
# Out:
#    total_bill   tip     sex smoker  day    time
# 0       16.99  1.01  Female     No  Sun  Dinner
# 1       10.34  1.66    Male     No  Sun  Dinner
# 2       21.01  3.50    Male     No  Sun  Dinner
# 3       23.68  3.31    Male     No  Sun  Dinner
# 4       24.59  3.61  Female     No  Sun  Dinner
# 5       25.29  4.71    Male     No  Sun  Dinner

# %% [markdown]
# loc는 **이름** 기반으로 가져오고 iloc는 **index** 기반으로 가져옴!!

# %%
tips.at[3,'day']
# Out:
# 'Sun'

# %%
tips.iat[3,4]
# Out:
# 'Sun'

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.groupby('smoker').mean()
# Out:
#         total_bill       tip      size
# smoker
# Yes      20.756344  3.008710  2.408602
# No       19.188278  2.991854  2.668874

# %%
x = tips.groupby('sex').mean()

# %%
x['ratio'] = x.tip/x.total_bill

# %%
x
# Out:
#         total_bill       tip      size     ratio
# sex
# Male     20.744076  3.089618  2.630573  0.148940
# Female   18.056897  2.833448  2.459770  0.156918

# %%
t = tips.groupby('smoker').mean()

# %%
t['ratio'] = t.tip / t.total_bill

# %%
t
# Out:
#         total_bill       tip      size     ratio
# smoker
# Yes      20.756344  3.008710  2.408602  0.144954
# No       19.188278  2.991854  2.668874  0.155921

# %%
accidents.describe()
# Out:
#               발생건수         사망자수         부상자수           중상           경상  \
# count  3255.000000  3255.000000  3255.000000  3255.000000  3255.000000
# mean     66.712135     1.161598    99.243318    22.813518    69.895853
# std     149.823021     1.922356   240.649627    45.094825   183.574030
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       4.500000     0.000000     5.000000     2.000000     2.000000
# 50%      14.000000     0.000000    17.000000     6.000000     9.000000
# 75%      50.500000     2.000000    68.000000    22.000000    40.000000
# max    1708.000000    21.000000  2931.000000   533.000000  2299.000000
#
#               부상신고
# count  3255.000000
# mean      6.533948
# std      18.823657
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       4.000000
# max     241.000000

# %%
tips.tip = tips.tip + 1

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  2.01  Female     No   Sun  Dinner     2
# 1         10.34  2.66    Male     No   Sun  Dinner     3
# 2         21.01  4.50    Male     No   Sun  Dinner     3
# 3         23.68  4.31    Male     No   Sun  Dinner     2
# 4         24.59  4.61  Female     No   Sun  Dinner     4
# 5         25.29  5.71    Male     No   Sun  Dinner     4
# 6          8.77  3.00    Male     No   Sun  Dinner     2
# 7         26.88  4.12    Male     No   Sun  Dinner     4
# 8         15.04  2.96    Male     No   Sun  Dinner     2
# 9         14.78  4.23    Male     No   Sun  Dinner     2
# 10        10.27  2.71    Male     No   Sun  Dinner     2
# 11        35.26  6.00  Female     No   Sun  Dinner     4
# 12        15.42  2.57    Male     No   Sun  Dinner     2
# 13        18.43  4.00    Male     No   Sun  Dinner     4
# 14        14.83  4.02  Female     No   Sun  Dinner     2
# ...

# %%
x = tips.total_bill.plot

# %%
x.bar()

# %%
tips.groupby('sex').mean()[['tip']].plot.bar()

# %%
data = accidents

# %%
data.shape
# Out:
# (3255, 10)

# %%
dust = pd.read_csv('b.csv', engine = 'python',encoding = 'cp949')

# %%
dust.columns[1]
# Out:
# ' 미세먼지농도 (㎍/㎥)'

# %%
dust.set_index('날짜')
# Out:
#              미세먼지농도 (㎍/㎥)  결과
# 날짜
# 2017-01-10             19  좋음
# 2017-01-11             20  좋음
# 2017-01-13             29  좋음
# 2017-01-14             40  보통
# 2017-01-20             20  좋음
# 2017-01-21             20  좋음
# 2017-01-27             25  좋음
# 2017-01-28             40  보통
# 2017-01-31             40  보통
# 2017-02-01             50  보통
# 2017-02-02             10  좋음
# 2017-02-03             22  좋음
# 2017-02-06             25  좋음
# 2017-02-07             27  좋음
# 2017-02-08             30  좋음
# 2017-02-09             41  보통
# 2017-02-10             42  보통
# 2017-02-11             19  좋음
# 2017-02-14             18  좋음
# 2017-02-15             20  좋음
# 2017-02-16             22  좋음
# 2017-02-17             43  보통
# 2017-02-22             43  보통
# 2017-02-23             41  보통
# 2017-02-24             20  좋음
# 2017-02-25             30  좋음
# 2017-02-26             35  보통
# 2017-02-27             37  보통
# 2017-03-01             38  보통
# 2017-03-02             39  보통
# ...

# %%
dust['date'] = pd.to_datetime(dust['날짜'])

# %%
dust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
# 날짜               250 non-null object
#  미세먼지농도 (㎍/㎥)    250 non-null int64
# 결과               250 non-null object
# date             250 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 7.9+ KB

# %%
dust.set_index('date')[dust.columns[1]]['2017-01']
# Out:
# date
# 2017-01-10    19
# 2017-01-11    20
# 2017-01-13    29
# 2017-01-14    40
# 2017-01-20    20
# 2017-01-21    20
# 2017-01-27    25
# 2017-01-28    40
# 2017-01-31    40
# Name:  미세먼지농도 (㎍/㎥), dtype: int64

# %%
dust.set_index('date')[dust.columns[1]].resample('M').mean().plot.line()

# %%
dust.set_index('date')[dust.columns[1]].plot.line()

# %% [markdown]
# # pandas
#
# # 기초 통계 분석(EDA = Exploratory Data Analysis)
#  - 통계값 분석
#  - graph
#
# # 전처리

# %%
dust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
# 날짜               250 non-null object
#  미세먼지농도 (㎍/㎥)    250 non-null int64
# 결과               250 non-null object
# date             250 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 7.9+ KB
